# %%
# %fs rm -r /user/hive/warehouse/compras
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res7: Boolean = true
# </div>

# %%
df = (spark.read
      .format("delta")
      .option("versionAsOf", "1")
      .load("/user/hive/warehouse/compras")
)
df.show()
# Out:
# +---+----------+--------+-----+---------------+----+
# | id|date_order|customer|price|        product|unit|
# +---+----------+--------+-----+---------------+----+
# |  2|2021-03-22|     Ana|121.6|AR-CONDICIONADO|   6|
# |  5|2021-05-23|  Tereza|412.0|       FRIGOBAR|   3|
# |  7|2021-07-25|   Sofia|342.3|        CADEIRA|   1|
# |  3|2021-04-21|   Sofia|415.4|        FREEZER|   7|
# |  6|2021-06-25|   Carla|124.0|           MESA|   1|
# |  4|2021-04-23|  Sandra|313.0|             TV|   8|
# |  1|2021-01-23|  Carlos|238.0|             TV|   5|
# +---+----------+--------+-----+---------------+----+

# %%
# %sql

SELECT COUNT(*) FROM compras VERSION AS OF 3 
--select count(*) from compras@v3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>7</td></tr></tbody></table></div>

# %%
# %sql

SELECT * FROM delta. `/user/hive/warehouse/compras`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
describe history compras;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql

INSERT INTO compras
SELECT * FROM compras VERSION AS OF 1
WHERE id = 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql

SELECT * FROM compras;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql

DESCRIBE HISTORY compras;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql

SELECT count(DISTINCT id) - (SELECT count(DISTINCT ID) FROM compras VERSION AS OF 4) AS `dif_registros` FROM compras
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dif_registros</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>
