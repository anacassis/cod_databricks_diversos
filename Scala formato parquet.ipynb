# %%
import pyspark

# %%
dataframe = spark.read.format("csv").option("header","true").load("/FileStore/tables/Datafiniti_Hotel_Reviews_Jun19-1.csv")
display(dataframe)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %scala
val  dataframscala = sqlContext.read.format("com.databricks.spark.csv").option("delimiter",",").option("header","true").load("/FileStore/tables/Datafiniti_Hotel_Reviews_Jun19-1.csv")
display(dataframscala)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dataframe.write.parquet("/FileStore/tables/csv-1.parquet")
